# %%
import pandas as pd

# %%
marks = pd.Series([90,80,70,60,50])
print(marks)
print()
custom = pd.Series([90,80,70], index = ['A','B','C'])
print(custom)
# Out:
# 0    90
# 1    80
# 2    70
# 3    60
# 4    50
# dtype: int64
#
# A    90
# B    80
# C    70
# dtype: int64

# %%
data = {'Name' : ['Jaskirat', 'Arnav', 'Harsh', 'Pranjal'],
        'Age' : [1,2,3,4],
        'Height' : [5.9, 5.2, 5.8, 6.1]
}

df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Height
# 0  Jaskirat    1     5.9
# 1     Arnav    2     5.2
# 2     Harsh    3     5.8
# 3   Pranjal    4     6.1

# %%
df.head(2)
# Out:
#        Name  Age  Height
# 0  Jaskirat    1     5.9
# 1     Arnav    2     5.2

# %%
df.tail(2)
# Out:
#       Name  Age  Height
# 2    Harsh    3     5.8
# 3  Pranjal    4     6.1
